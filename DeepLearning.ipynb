# %% [markdown]
# <a href="https://colab.research.google.com/github/DesiArti/DEEPLEARNING/blob/main/DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip uninstall transformers -y
# Out:
# Found existing installation: transformers 4.35.2
# Uninstalling transformers-4.35.2:
#   Successfully uninstalled transformers-4.35.2

# %%
! pip install git+https://github.com/zphang/transformers@llama_push
# Out:
# Collecting git+https://github.com/zphang/transformers@llama_push
#   Cloning https://github.com/zphang/transformers (to revision llama_push) to /tmp/pip-req-build-q7c_4eqs
#   Running command git clone --filter=blob:none --quiet https://github.com/zphang/transformers /tmp/pip-req-build-q7c_4eqs
#   Running command git checkout -b llama_push --track origin/llama_push
#   Switched to a new branch 'llama_push'
#   Branch 'llama_push' set up to track remote branch 'llama_push' from 'origin'.
#   Resolved https://github.com/zphang/transformers to commit 3884da12ce327667d4df5101aef3533cc32be61f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.0.dev0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 31.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0.dev0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0.dev0) (2023.11.17)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.27.0.dev0-py3-none-any.whl size=6688481 sha256=91aa1dbdd9fc4e2609694dbfb1532df5e34a1e5d7f49f3efc83a7f52591047e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7t8441ij/wheels/d3/9c/f3/fd6c7f19022e6f93d62243b63c293c9c7e4a4781d8e4a7fc39
# Successfully built transformers
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
# Successfully installed tokenizers-0.13.3 transformers-4.27.0.dev0

# %%
! pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.27.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
from google.colab import drive
# Path ke file token di Google Drive
token_file_path = '/content/drive/MyDrive/Colab Notebooks/hf_token.txt'

# Baca isi file token
with open(token_file_path, 'r') as file:
    hf_token = file.read()

# %%
from transformers import pipeline

pl = pipeline("text-generation", model="medalpaca/medalpaca-7b", tokenizer="medalpaca/medalpaca-7b", max_new_tokens = 1000)
question = "What are the symptoms of diabetes?"
context = "Diabetes is a metabolic disease that causes high blood sugar. The symptoms include increased thirst, frequent urination, and unexplained weight loss."
answer = pl(f"Context: {context}\n\nQuestion: {question}\n\nAnswer: ")
print(answer)
# Out:
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.88G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.89G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/7.18G [00:00<?, ?B/s]

# %%
input_text = "Can you tell me the most dangerous disease in Indonesia ?"
model = pl
response = model(input_text)[0]["generated_text"]
response = response.replace(input_text, "Answer: ")
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f095c40131b> in <cell line: 2>()
#       1 input_text = "Can you tell me the most dangerous disease in Indonesia ?"
# ----> 2 model = pl
#       3 response = model(input_text)[0]["generated_text"]
#       4 response = response.replace(input_text, "Answer: ")
#       5 response
#
# NameError: name 'pl' is not defined

# %%
input_text = "Can you explain about Medalpaca for me?"
response = model(input_text)[0]["generated_text"]
response = response.replace(input_text, "Answer: ")
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aff1d7cef5b2> in <cell line: 2>()
#       1 input_text = "Can you explain about Medalpaca?"
# ----> 2 response = model(input_text)[0]["generated_text"]
#       3 response = response.replace(input_text, "Answer: ")
#       4 response
#
# NameError: name 'model' is not defined

# %%
input_text = "How can we stay safe from the flu?"
response = model(input_text)[0]["generated_text"]
response = response.replace(input_text, "Answer: ")
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8eec5df3c105> in <cell line: 2>()
#       1 input_text = "How can we stay safe from the Coronavirus?"
# ----> 2 response = model(input_text)[0]["generated_text"]
#       3 response = response.replace(input_text, "Answer: ")
#       4 response
#
# NameError: name 'model' is not defined
