# %% [markdown]
# <a href="https://colab.research.google.com/github/DesiArti/DEEPLEARNING/blob/main/UTSADLDesi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install library ultralytics
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 13.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Create a new YOLO model from scratch
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 123MB/s]

# %%
# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='coco128.yaml', epochs=3)
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:07<00:00,  1.08it/s]
#                    all        128        929      0.665      0.546      0.625      0.463
#                 person        128        254      0.803      0.675      0.775      0.554
#                bicycle        128          6      0.579      0.333      0.319      0.281
#                    car        128         46      0.717      0.217      0.276      0.182
#             motorcycle        128          5      0.828      0.967      0.928      0.737
# ...

# %%
# Perform object detection on an image using the model
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 16.8MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 16.6ms
# Speed: 4.2ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)

# %%
# Run inference on 'bus.jpg' with arguments
model.predict('bus.jpg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 77.5ms
# Speed: 1.5ms preprocess, 77.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs/detect/train3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
Image(filename=f'/content/runs/detect/train3/bus.jpg',width=600)

# %%
# Export the model to ONNX format
success = model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 83.1 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.1s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 8.9s, saved as 'runs/detect/train/weights/best.onnx' (12.2 MB)
#
# Export complete (10.6s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# ...

# %% [markdown]
# Model dengan DataSet dari roboflow

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AjLZpgB0ukgHiytR77Mp")
project = rf.workspace("roboflow-100").project("apples-fvpl5")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
from ultralytics import YOLO
# Create a new YOLO model from scratch
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')

# %%
# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='/content/apples-2/data.yaml', epochs=3)
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/apples-2/valid/labels.cache... 178 images, 0 backgrounds, 0 corrupt: 100%|██████████| 178/178 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [00:05<00:00,  2.11it/s]
#                    all        178        723      0.612      0.651       0.63      0.412
#                  apple        178        522      0.554      0.787      0.658       0.39
#          damaged_apple        178        201       0.67      0.515      0.602      0.433
# Speed: 0.3ms preprocess, 7.6ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to runs/detect/train82

# %%
# Perform object detection on an image using the model
results = model('/content/apple.jpeg')
# Out:
# image 1/1 /content/apple.jpeg: 448x640 3 apples, 196.7ms
# Speed: 2.6ms preprocess, 196.7ms inference, 10.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Run inference on 'apple' with arguments
model.predict('/content/apple.jpeg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/apple.jpeg: 224x320 2 apples, 57.2ms
# Speed: 1.3ms preprocess, 57.2ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/detect/train86
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'apple', 1: 'damaged_apple'}
#  orig_img: array([[[ 72, 191, 146],
#          [ 76, 193, 148],
#          [ 80, 195, 152],
#          ...,
#          [  3, 132,  63],
#          [  4, 133,  64],
#          [  3, 135,  65]],
#
#         [[ 74, 191, 146],
#          [ 76, 193, 148],
#          [ 82, 194, 152],
#          ...,
#          [ 22, 152,  87],
#          [ 23, 154,  87],
#          [ 23, 155,  88]],
#
#         [[ 74, 189, 145],
#          [ 76, 191, 147],
#          [ 82, 194, 152],
#          ...,
#          [ 40, 172, 112],
#          [ 41, 174, 112],
#          [ 40, 175, 113]],
#
#         ...,
#
# ...

# %%
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
Image(filename=f'/content/runs/detect/train86/apple.jpeg')
